# %% [markdown]
# <a href="https://colab.research.google.com/github/dev-PrabhatShukla/Python-Libraries-For-Data-Science-Self-Notes/blob/main/Assignment_Pandas_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# # <b> Problem 1: Import Pandas and Numpy in the notebook </b>

# %%
# Import statements
import numpy as np
import pandas as pd

# %% [markdown]
# # <b> Problem 2 : Load the automobile_data.csv kept in the shared folder

# %%
# Mount your drive and read the csv file. Make sure you are using the correct file path
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Loading automobile_data.csv file now

file_path = '/content/drive/MyDrive/Colab Notebooks/AlmaBetter/Module 1 : Python for Data Science/Week 3/Pandas Operations/DataSet/automobile_data.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# # <b> Problem 3 : Do a basic inspection and print the first and last 15 rows of your dataframe

# %%
# Your code here
# Firstly print the complete dataset
df
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3                 ?  alfa-romero  ...       21          27  13495
# 1            3                 ?  alfa-romero  ...       21          27  16500
# 2            1                 ?  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
# Now Print First 15 rows from Dataset
df.head(15)
# Out:
#     symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0           3                 ?  alfa-romero  ...       21          27  13495
# 1           3                 ?  alfa-romero  ...       21          27  16500
# 2           1                 ?  alfa-romero  ...       19          26  16500
# 3           2               164         audi  ...       24          30  13950
# 4           2               164         audi  ...       18          22  17450
# 5           2                 ?         audi  ...       19          25  15250
# 6           1               158         audi  ...       19          25  17710
# 7           1                 ?         audi  ...       19          25  18920
# 8           1               158         audi  ...       17          20  23875
# 9           0                 ?         audi  ...       16          22      ?
# 10          2               192          bmw  ...       23          29  16430
# 11          0               192          bmw  ...       23          29  16925
# 12          0               188          bmw  ...       21          28  20970
# 13          0               188          bmw  ...       21          28  21105
# 14          1                 ?          bmw  ...       20          25  24565
#
# [15 rows x 26 columns]

# %%
# Now Print last 15 rows from Dataset
df.tail(15)
# Out:
#      symboling normalized-losses        make  ... city-mpg highway-mpg  price
# 190          3               256  volkswagen  ...       24          29   9980
# 191          0                 ?  volkswagen  ...       19          24  13295
# 192          0                 ?  volkswagen  ...       33          38  13845
# 193          0                 ?  volkswagen  ...       25          31  12290
# 194         -2               103       volvo  ...       23          28  12940
# 195         -1                74       volvo  ...       23          28  13415
# 196         -2               103       volvo  ...       24          28  15985
# 197         -1                74       volvo  ...       24          28  16515
# 198         -2               103       volvo  ...       17          22  18420
# 199         -1                74       volvo  ...       17          22  18950
# 200         -1                95       volvo  ...       23          28  16845
# 201         -1                95       volvo  ...       19          25  19045
# 202         -1                95       volvo  ...       18          23  21485
# 203         -1                95       volvo  ...       26          27  22470
# 204         -1                95       volvo  ...       19          25  22625
#
# [15 rows x 26 columns]

# %% [markdown]
# # <b>Problem 4 : You need to clean the data a little bit now. Replace all column values with the values <code>?</code> and <code>n.a</code> with <code>NaN</code>

# %%
# Your code here
df.loc[: , :].replace(['?','n.a'],['NaN', 'NaN'])
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3               NaN  alfa-romero  ...       21          27  13495
# 1            3               NaN  alfa-romero  ...       21          27  16500
# 2            1               NaN  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
df = df.replace(r'?', np.NaN)                                                   # replacing ? mark With np.nan
df = df.replace(r'n.a', np.NaN)                                                  # replacing n.a With np.nan
df

# %%
df.info
# Out:
# <bound method DataFrame.info of      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3               NaN  alfa-romero  ...       21          27  13495
# 1            3               NaN  alfa-romero  ...       21          27  16500
# 2            1               NaN  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]>

# %% [markdown]
# # <b>Problem 5 : Print the company name which manufactured the most expensive car. Also print the price of the most expensive car

# %%
id_max_car_price = df['price'].fillna(0).astype('int32').argmax()
max_car_price = df['price'].fillna(0).astype('int32').max()

# %%
print(f"The most expensive car is manufactured by {df['make'][id_max_car_price]} which costs total of {max_car_price} dollars.")
# Out:
# The most expensive car is manufactured by mercedes-benz which costs total of 45400 dollars

# %% [markdown]
# # <b>Problem 6 : Calculate maximum horsepowers for each company. </b>

# %%
# Your code here
df.groupby(["make"]).agg({'horsepower': max}).reset_index()
# Out:
#              make horsepower
# 0     alfa-romero        154
# 1            audi        160
# 2             bmw        182
# 3       chevrolet         70
# 4           dodge         88
# 5           honda         86
# 6           isuzu         90
# 7          jaguar        262
# 8           mazda         84
# 9   mercedes-benz        184
# 10        mercury        175
# 11     mitsubishi         88
# 12         nissan         97
# 13         peugot         97
# 14       plymouth         88
# 15        porsche        288
# 16        renault        NaN
# 17           saab        160
# 18         subaru         94
# 19         toyota         92
# 20     volkswagen         90
# 21          volvo        162

# %% [markdown]
# # <b> Problem 7 : Print the total number of cars manufactured by each company

# %%
# Your code here
df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# alfa-romero       3
# chevrolet         3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# # <b> Problem 8 : Create a new column for the updated price. This updated price will be calculated on top of the given price - if the engine is in front, price will be same else if the engine is in rear, price will be doubled </b>

# %%
df.head(60)
# Out:
#     symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0           3               NaN  alfa-romero  ...       21          27  13495
# 1           3               NaN  alfa-romero  ...       21          27  16500
# 2           1               NaN  alfa-romero  ...       19          26  16500
# 3           2               164         audi  ...       24          30  13950
# 4           2               164         audi  ...       18          22  17450
# 5           2               NaN         audi  ...       19          25  15250
# 6           1               158         audi  ...       19          25  17710
# 7           1               NaN         audi  ...       19          25  18920
# 8           1               158         audi  ...       17          20  23875
# 9           0               NaN         audi  ...       16          22    NaN
# 10          2               192          bmw  ...       23          29  16430
# 11          0               192          bmw  ...       23          29  16925
# 12          0               188          bmw  ...       21          28  20970
# 13          0               188          bmw  ...       21          28  21105
# 14          1               NaN          bmw  ...       20          25  24565
# 15          0               NaN          bmw  ...       16          22  30760
# 16          0               NaN          bmw  ...       16          22  41315
# 17          0               NaN          bmw  ...       15          20  36880
# 18          2               121    chevrolet  ...       47          53   5151
# 19          1                98    chevrolet  ...       38          43   6295
# 20          0                81    chevrolet  ...       38          43   6575
# 21          1               118        dodge  ...       37          41   5572
# 22          1               118        dodge  ...       31          38   6377
# 23          1               118        dodge  ...       24          30   7957
# 24          1               148        dodge  ...       31          38   6229
# 25          1               148        dodge  ...       31          38   6692
# 26          1               148        dodge  ...       31          38   7609
# 27          1               148        dodge  ...       24          30   8558
# 28         -1               110        dodge  ...       24          30   8921
# 29          3               145        dodge  ...       19          24  12964
# 30          2               137        honda  ...       49          54   6479
# 31          2               137        honda  ...       31          38   6855
# 32          1               101        honda  ...       38          42   5399
# 33          1               101        honda  ...       30          34   6529
# 34          1               101        honda  ...       30          34   7129
# 35          0               110        honda  ...       30          34   7295
# 36          0                78        honda  ...       30          34   7295
# 37          0               106        honda  ...       27          33   7895
# 38          0               106        honda  ...       27          33   9095
# 39          0                85        honda  ...       27          33   8845
# 40          0                85        honda  ...       27          33  10295
# 41          0                85        honda  ...       24          28  12945
# 42          1               107        honda  ...       25          31  10345
# 43          0               NaN        isuzu  ...       24          29   6785
# 44          1               NaN        isuzu  ...       38          43    NaN
# 45          0               NaN        isuzu  ...       38          43    NaN
# 46          2               NaN        isuzu  ...       24          29  11048
# 47          0               145       jaguar  ...       15          19  32250
# 48          0               NaN       jaguar  ...       15          19  35550
# 49          0               NaN       jaguar  ...       13          17  36000
# 50          1               104        mazda  ...       30          31   5195
# 51          1               104        mazda  ...       31          38   6095
# 52          1               104        mazda  ...       31          38   6795
# 53          1               113        mazda  ...       31          38   6695
# 54          1               113        mazda  ...       31          38   7395
# 55          3               150        mazda  ...       17          23  10945
# 56          3               150        mazda  ...       17          23  11845
# 57          3               150        mazda  ...       17          23  13645
# 58          3               150        mazda  ...       16          23  15645
# 59          1               129        mazda  ...       26          32   8845
#
# [60 rows x 26 columns]

# %%
# Your code here. Use apply and lambda
def check_engine(engine, price):
  """Dobble the price for rear typed engine cars"""
  if engine=='front':
    return 1*price
  else:
    return 2*int(price)

df['updated_price'] = df.apply(lambda x : check_engine(x['engine-location'], x['price']), axis=1)

# %%
df[df['engine-location'] == "rear"]
# Out:
#      symboling normalized-losses     make  ... highway-mpg  price updated_price
# 126          3               NaN  porsche  ...          25  32528         65056
# 127          3               NaN  porsche  ...          25  34028         68056
# 128          3               NaN  porsche  ...          25  37028         74056
#
# [3 rows x 27 columns]

# %% [markdown]
# # <b>Problem 9 : Sort the dataframe by car and price columns

# %%
df.head()
# Out:
#    symboling normalized-losses         make  ... highway-mpg  price updated_price
# 0          3               NaN  alfa-romero  ...          27  13495         13495
# 1          3               NaN  alfa-romero  ...          27  16500         16500
# 2          1               NaN  alfa-romero  ...          26  16500         16500
# 3          2               164         audi  ...          30  13950         13950
# 4          2               164         audi  ...          22  17450         17450
#
# [5 rows x 27 columns]

# %%
# Your code here
df.sort_values(['make', 'price'], inplace=True)
df.head(10)
# Out:
#    symboling normalized-losses         make  ... highway-mpg  price updated_price
# 0          3               NaN  alfa-romero  ...          27  13495         13495
# 1          3               NaN  alfa-romero  ...          27  16500         16500
# 2          1               NaN  alfa-romero  ...          26  16500         16500
# 3          2               164         audi  ...          30  13950         13950
# 5          2               NaN         audi  ...          25  15250         15250
# 4          2               164         audi  ...          22  17450         17450
# 6          1               158         audi  ...          25  17710         17710
# 7          1               NaN         audi  ...          25  18920         18920
# 8          1               158         audi  ...          20  23875         23875
# 9          0               NaN         audi  ...          22    NaN           NaN
#
# [10 rows x 27 columns]

# %% [markdown]
# # <b> Problem 10 : Create a new column which stores the number of doors in a car as integers.

# %%
# Your code here. Use apply
print(df['num-of-doors'].value_counts())
def string_to_int(no_of_doors):
    """Converts the string no of doors to integer value"""
    if no_of_doors== 'four':
        no_of_doors=4
        return no_of_doors
    else:
        no_of_doors=2
        return no_of_doors

df['num-of-doors'] = df.apply(lambda x: string_to_int(x['num-of-doors']),axis=1)
df.head()
# Out:
# 4    114
# 2     91
# Name: num-of-doors, dtype: int64
#    symboling normalized-losses         make  ... highway-mpg  price  updated_price
# 0          3               NaN  alfa-romero  ...          27  13495          13495
# 1          3               NaN  alfa-romero  ...          27  16500          16500
# 2          1               NaN  alfa-romero  ...          26  16500          16500
# 3          2               164         audi  ...          30  13950          13950
# 5          2               NaN         audi  ...          25  15250          15250
#
# [5 rows x 27 columns]

# %% [markdown]
# # <b>Problem 11 : Concatenate the two data frames given below firstly row wise and secondly column wise.</b>
#
# <code>GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}</code>
#
# <code>japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}</code>

# %%
# Your code here
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}

japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
df_GermanCars = pd.DataFrame(GermanCars)
df_japaneseCars = pd.DataFrame(japaneseCars)

# %%
# Row wise concatenate firstly
pd.concat([df_GermanCars, df_japaneseCars], axis=1)

# Then Column wise concatenate it
pd.concat([df_GermanCars, df_japaneseCars])
# Out:
#        Company   Price
# 0         Ford   23845
# 1     Mercedes  171995
# 2          BMV  135925
# 3         Audi   71400
# 0       Toyota   29995
# 1        Honda   23600
# 2       Nissan   61500
# 3  Mitsubishi    58900
